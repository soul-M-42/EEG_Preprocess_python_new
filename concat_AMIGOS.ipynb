# %%
import os
import numpy as np
import scipy.io as sio

# 配置参数
n_trials = 20  # 每个被试的最大 trial 数
sampling_rate = 125  # 采样率 (Hz)
n_sub = 40  # 总的被试数量

# 输入和输出目录
input_dir = r'Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS'  # 输入目录
output_dir = r'Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT'  # 输出目录
os.makedirs(output_dir, exist_ok=True)

def get_trial_shape(sub_id, trial_id):
    """
    动态获取 trial 的形状，使用其他未缺失 trial 的被试数据作为参考。
    """
    for other_sub_id in range(n_sub):
        if other_sub_id != sub_id:  # 跳过当前被试
            trial_path = os.path.join(input_dir, f'sub_{other_sub_id}', f'eeg_sub_{other_sub_id}_trial_{trial_id}.npy')
            if os.path.exists(trial_path):
                trial_data = np.load(trial_path)  # 读取参考 trial
                return trial_data.shape  # 返回参考 trial 的形状
    raise ValueError(f"No valid trial data found for trial {trial_id}.")  # 没有任何参考 trial 时抛出异常

def process_subject(sub_id):
    """
    处理单个被试数据，将所有 trial 拼接并生成对应 .mat 文件。
    """
    sub_dir = os.path.join(input_dir, f'sub_{sub_id}')
    merged_data_all_cleaned = []  # 存储拼接后的数据
    merged_n_samples_one = []    # 存储每个 trial 的时长信息（以秒为单位）
    missing_trials = []          # 存储缺失的 trial 索引

    for trial_id in range(n_trials):
        trial_path = os.path.join(sub_dir, f'eeg_sub_{sub_id}_trial_{trial_id}.npy')
        
        if os.path.exists(trial_path):
            # 读取矩阵
            trial_data = np.load(trial_path)  # Shape: [n_channel, n_timepoints]
        else:
            # 如果 trial 文件缺失，用高斯噪声替代
            print(f"Missing trial detected: sub_{sub_id} trial_{trial_id}, replacing with noise.")
            trial_shape = get_trial_shape(sub_id, trial_id)  # 动态获取参考 trial 的形状
            trial_data = np.random.normal(loc=0, scale=1, size=trial_shape)  # 生成高斯噪声
            missing_trials.append(trial_id)

        # 添加到拼接矩阵
        merged_data_all_cleaned.append(trial_data)
        # 记录 trial 时长（单位：秒）
        merged_n_samples_one.append(trial_data.shape[1] / sampling_rate)

    # 拼接所有 trial 在时间轴上（按列拼接）
    merged_data_all_cleaned = np.hstack(merged_data_all_cleaned)  # Shape: [n_channel, total_timepoints]
    merged_n_samples_one = np.array(merged_n_samples_one).reshape(1, -1)  # Shape: [1, n_trial]

    # 保存到 .mat 文件
    output_file = os.path.join(output_dir, f'sub_{sub_id}_processed.mat')
    sio.savemat(output_file, {
        'merged_data_all_cleaned': merged_data_all_cleaned.astype(np.double),
        'merged_n_samples_one': merged_n_samples_one.astype(np.double),
        'missing_trials': np.array(missing_trials, dtype=np.int32)  # 保存缺失的 trial 索引
    })
    print(f"Processed sub_{sub_id} saved to {output_file}")

# 主循环：遍历所有被试
for sub_id in range(n_sub):
    sub_dir = os.path.join(input_dir, f'sub_{sub_id}')
    if os.path.exists(sub_dir):
        process_subject(sub_id)
    else:
        print(f"Directory for sub_{sub_id} not found. Skipping.")
# Out:
# Processed sub_0 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_0_processed.mat
# Processed sub_1 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_1_processed.mat
# Processed sub_2 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_2_processed.mat
# Processed sub_3 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_3_processed.mat
# Processed sub_4 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_4_processed.mat
# Processed sub_5 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_5_processed.mat
# Processed sub_6 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_6_processed.mat
# Missing trial detected: sub_7 trial_16, replacing with noise.
# Missing trial detected: sub_7 trial_17, replacing with noise.
# Missing trial detected: sub_7 trial_18, replacing with noise.
# Missing trial detected: sub_7 trial_19, replacing with noise.
# Processed sub_7 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_7_processed.mat
# Processed sub_8 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_8_processed.mat
# Processed sub_9 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_9_processed.mat
# Processed sub_10 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_10_processed.mat
# Missing trial detected: sub_11 trial_4, replacing with noise.
# Processed sub_11 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_11_processed.mat
# Processed sub_12 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_12_processed.mat
# Missing trial detected: sub_13 trial_16, replacing with noise.
# Processed sub_13 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_13_processed.mat
# Processed sub_14 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_14_processed.mat
# Processed sub_15 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_15_processed.mat
# Missing trial detected: sub_16 trial_17, replacing with noise.
# Missing trial detected: sub_16 trial_18, replacing with noise.
# Processed sub_16 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_16_processed.mat
# Missing trial detected: sub_17 trial_19, replacing with noise.
# Processed sub_17 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_17_processed.mat
# Processed sub_18 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_18_processed.mat
# Missing trial detected: sub_19 trial_7, replacing with noise.
# Processed sub_19 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_19_processed.mat
# Missing trial detected: sub_20 trial_1, replacing with noise.
# Missing trial detected: sub_20 trial_10, replacing with noise.
# Processed sub_20 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_20_processed.mat
# Missing trial detected: sub_21 trial_15, replacing with noise.
# Missing trial detected: sub_21 trial_18, replacing with noise.
# Processed sub_21 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_21_processed.mat
# Missing trial detected: sub_22 trial_0, replacing with noise.
# Missing trial detected: sub_22 trial_4, replacing with noise.
# Missing trial detected: sub_22 trial_6, replacing with noise.
# Missing trial detected: sub_22 trial_8, replacing with noise.
# Missing trial detected: sub_22 trial_11, replacing with noise.
# Processed sub_22 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_22_processed.mat
# Missing trial detected: sub_23 trial_0, replacing with noise.
# Missing trial detected: sub_23 trial_7, replacing with noise.
# Missing trial detected: sub_23 trial_11, replacing with noise.
# Missing trial detected: sub_23 trial_12, replacing with noise.
# Missing trial detected: sub_23 trial_13, replacing with noise.
# Missing trial detected: sub_23 trial_14, replacing with noise.
# Missing trial detected: sub_23 trial_15, replacing with noise.
# Missing trial detected: sub_23 trial_16, replacing with noise.
# Missing trial detected: sub_23 trial_17, replacing with noise.
# Missing trial detected: sub_23 trial_18, replacing with noise.
# Missing trial detected: sub_23 trial_19, replacing with noise.
# Processed sub_23 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_23_processed.mat
# Processed sub_24 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_24_processed.mat
# Processed sub_25 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_25_processed.mat
# Processed sub_26 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_26_processed.mat
# Missing trial detected: sub_27 trial_16, replacing with noise.
# Missing trial detected: sub_27 trial_17, replacing with noise.
# Missing trial detected: sub_27 trial_18, replacing with noise.
# Missing trial detected: sub_27 trial_19, replacing with noise.
# Processed sub_27 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_27_processed.mat
# Processed sub_28 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_28_processed.mat
# Processed sub_29 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_29_processed.mat
# Processed sub_30 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_30_processed.mat
# Processed sub_31 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_31_processed.mat
# Missing trial detected: sub_32 trial_0, replacing with noise.
# Missing trial detected: sub_32 trial_1, replacing with noise.
# Missing trial detected: sub_32 trial_2, replacing with noise.
# Missing trial detected: sub_32 trial_6, replacing with noise.
# Missing trial detected: sub_32 trial_7, replacing with noise.
# Missing trial detected: sub_32 trial_8, replacing with noise.
# Missing trial detected: sub_32 trial_9, replacing with noise.
# Missing trial detected: sub_32 trial_10, replacing with noise.
# Missing trial detected: sub_32 trial_12, replacing with noise.
# Missing trial detected: sub_32 trial_15, replacing with noise.
# Processed sub_32 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_32_processed.mat
# Processed sub_33 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_33_processed.mat
# Processed sub_34 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_34_processed.mat
# Missing trial detected: sub_35 trial_10, replacing with noise.
# Processed sub_35 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_35_processed.mat
# Processed sub_36 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_36_processed.mat
# Processed sub_37 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_37_processed.mat
# Processed sub_38 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_38_processed.mat
# Processed sub_39 saved to Z:/qingzhu/AutoICA_Processed_EEG/AMIGOS/Processed_MAT\sub_39_processed.mat
